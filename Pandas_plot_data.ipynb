# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather_info = pd.read_csv("weather.csv")
weather_excel = weather_info.to_excel("excel_format.xlsx",sheet_name="Weather_list")
weather_info
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
weather_info["Humidity3pm"].plot()
# Out:
# <AxesSubplot:>

# %%
data_to_plot =weather_info.head(10)
data_to_plot.plot.graph( x = "MinTemp" , y = "MaxTemp",figsize = (10,10))  
#plt.legend("mintemp","maxtemp")
#plt.legend(["mintemp" , "maxtemp"], loc= 'upper left')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7252/4157435675.py in <module>
#       1 data_to_plot =weather_info.head(10)
# ----> 2 data_to_plot.plot.graph( x = "MinTemp" , y = "MaxTemp",figsize = (10,10))
#       3 #plt.legend("mintemp","maxtemp")
#       4 #plt.legend(["mintemp" , "maxtemp"], loc= 'upper left')
#
# AttributeError: 'PlotAccessor' object has no attribute 'graph'

# %%
#weather_info.head(5)
axs = weather_info[["Rainfall","Evaporation","Sunshine"]].head(5).plot.area(figsize=(20, 10), subplots=True)

# %%
fig ,axs = plt.subplots(figsize=(15, 10))
weather_info[["Rainfall","Evaporation","Sunshine"]].plot.area(ax=axs)
axs.set_ylabel("Y_Plot")
axs.set_xlabel("X_Plot")
axs.set_title("Graphical representation of Rainfall,Evapouration and shine")
fig.savefig("weather_report.png")

                                                             
#weather_info.plot.area(ax=axs)
